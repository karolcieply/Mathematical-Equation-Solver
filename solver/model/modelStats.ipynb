# %%
from solverModel import SolverModel, DataProcessing, KNN
import sklearn.metrics as metrics
from pretty_confusion_matrix import pp_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import io
from PIL import Image

# %%
sm = SolverModel()
# Out:
# INFO:root:Model Created

# %%
X_train, y_train, X_test, y_test = DataProcessing.prepareTrainTestSet()

# %%
sm.fitModel(trainTestTuple=(X_train, y_train, X_test, y_test))
# Out:
# INFO:root:Model fitted
# INFO:root:Model Score: 0.9688

# %%
df_cm = pd.DataFrame(metrics.confusion_matrix(y_test, sm.predict(X_test)), index=range(10), columns=range(10))
pp_matrix(df_cm, cmap="magma")

# %%
print(metrics.classification_report(y_test, sm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       980
#            1       0.95      1.00      0.98      1135
#            2       0.98      0.96      0.97      1032
#            3       0.96      0.97      0.97      1010
#            4       0.98      0.96      0.97       982
#            5       0.97      0.97      0.97       892
#            6       0.98      0.99      0.98       958
#            7       0.96      0.96      0.96      1028
#            8       0.99      0.94      0.96       974
#            9       0.96      0.95      0.95      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
sns.histplot(y_train, bins=10)
plt.title("Training Set")
# Out:
# Text(0.5, 1.0, 'Training Set')

# %%
with open("C:\\Users\\Karol\\Documents\\GitHub\\Mathematical-Equation-Solver\\static\\images\\solution.png", "rb") as f:
    img = Image.open(io.BytesIO(f.read())).convert('L')
DataProcessing.plotComparisonImage(img, DataProcessing.compressImage(img).reshape(28,28), "Before Compression", "After Compression")

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(X_train, y_train)
df_cm = pd.DataFrame(metrics.confusion_matrix(y_test, clf.predict(X_test)), index=range(10), columns=range(10))
pp_matrix(df_cm, cmap="magma")
print(metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.98      1032
#            3       0.97      0.99      0.98      1010
#            4       0.98      0.98      0.98       982
#            5       0.99      0.98      0.98       892
#            6       0.99      0.99      0.99       958
#            7       0.98      0.97      0.97      1028
#            8       0.97      0.98      0.97       974
#            9       0.97      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
clf = SVC(kernel="poly")
clf.fit(X_train, y_train)
df_cm = pd.DataFrame(metrics.confusion_matrix(y_test, clf.predict(X_test)), index=range(10), columns=range(10))
pp_matrix(df_cm, cmap="magma")
print(metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.97      0.99      0.98      1135
#            2       0.98      0.97      0.98      1032
#            3       0.98      0.97      0.98      1010
#            4       0.97      0.98      0.98       982
#            5       0.97      0.97      0.97       892
#            6       0.98      0.98      0.98       958
#            7       0.97      0.97      0.97      1028
#            8       0.98      0.97      0.98       974
#            9       0.97      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
clf = SVC(kernel="rbf")
clf.fit(X_train, y_train)
df_cm = pd.DataFrame(metrics.confusion_matrix(y_test, clf.predict(X_test)), index=range(10), columns=range(10))
pp_matrix(df_cm, cmap="magma")
print(metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.98      1032
#            3       0.97      0.99      0.98      1010
#            4       0.98      0.98      0.98       982
#            5       0.99      0.98      0.98       892
#            6       0.99      0.99      0.99       958
#            7       0.98      0.97      0.97      1028
#            8       0.97      0.98      0.97       974
#            9       0.97      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(X_train, y_train)
df_cm = pd.DataFrame(metrics.confusion_matrix(y_test, clf.predict(X_test)), index=range(10), columns=range(10))
pp_matrix(df_cm, cmap="magma")
print(metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       980
#            1       0.85      0.95      0.90      1135
#            2       0.90      0.26      0.40      1032
#            3       0.71      0.35      0.47      1010
#            4       0.88      0.17      0.29       982
#            5       0.55      0.05      0.09       892
#            6       0.65      0.93      0.77       958
#            7       0.88      0.27      0.42      1028
#            8       0.28      0.67      0.40       974
#            9       0.37      0.95      0.53      1009
#
#     accuracy                           0.56     10000
#    macro avg       0.69      0.55      0.51     10000
# weighted avg       0.69      0.56      0.52     10000

# %%
from solverModel import SolverModel, DataProcessing, KNN, myThread
X_train, y_train, X_test, y_test = DataProcessing.prepareTrainTestSet()
knn = KNN(5, 2)
knn.fit(X_train, y_train)
score = knn.startScoreMultiThreaded(X_test, y_test)
